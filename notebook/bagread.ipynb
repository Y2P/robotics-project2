# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
import rosbag_pandas

# %%
df = rosbag_pandas.bag_to_dataframe('../bags/imu_bag.bag')

# %%
df.shape
# Out:
# (288688, 71)

# %%
df.columns
# Out:
# Index([u'cmd_vel__angular_x', u'cmd_vel__angular_y', u'cmd_vel__angular_z',
#        u'cmd_vel__linear_x', u'cmd_vel__linear_y', u'cmd_vel__linear_z',
#        u'imu__angular_velocity_covariance0',
#        u'imu__angular_velocity_covariance1',
#        u'imu__angular_velocity_covariance2',
#        u'imu__angular_velocity_covariance3',
#        u'imu__angular_velocity_covariance4',
#        u'imu__angular_velocity_covariance5',
#        u'imu__angular_velocity_covariance6',
#        u'imu__angular_velocity_covariance7',
#        u'imu__angular_velocity_covariance8', u'imu__angular_velocity_x',
#        u'imu__angular_velocity_y', u'imu__angular_velocity_z',
#        u'imu__linear_acceleration_covariance0',
#        u'imu__linear_acceleration_covariance1',
#        u'imu__linear_acceleration_covariance2',
#        u'imu__linear_acceleration_covariance3',
#        u'imu__linear_acceleration_covariance4',
#        u'imu__linear_acceleration_covariance5',
# ...

# %%
df.sample(10)
# Out:
#                                cmd_vel__angular_x  cmd_vel__angular_y  \
# 2018-04-12 12:55:44.995216128                 NaN                 NaN
# 2018-04-12 12:58:17.383726336                 NaN                 NaN
# 2018-04-12 12:56:32.937122304                 NaN                 NaN
# 2018-04-12 12:58:37.635142912                 NaN                 NaN
# 2018-04-12 12:57:41.833773824                 NaN                 NaN
# 2018-04-12 12:58:03.564569600                 NaN                 NaN
# 2018-04-12 12:54:27.806438144                 NaN                 NaN
# 2018-04-12 12:57:50.295631872                 NaN                 NaN
# 2018-04-12 12:58:37.966044672                 NaN                 NaN
# 2018-04-12 12:54:47.879018240                 NaN                 NaN
#
#                                cmd_vel__angular_z  cmd_vel__linear_x  \
# 2018-04-12 12:55:44.995216128                 NaN                NaN
# ...

# %%
df.describe()
# Out:
#        cmd_vel__angular_x  cmd_vel__angular_y  cmd_vel__angular_z  \
# count              8198.0              8198.0         8198.000000
# mean                  0.0                 0.0           -0.016821
# std                   0.0                 0.0            0.885469
# min                   0.0                 0.0           -2.413274
# 25%                   0.0                 0.0           -0.391246
# 50%                   0.0                 0.0            0.000000
# 75%                   0.0                 0.0            0.291595
# max                   0.0                 0.0            2.912685
#
#        cmd_vel__linear_x  cmd_vel__linear_y  cmd_vel__linear_z  \
# count        8198.000000             8198.0             8198.0
# mean            0.349689                0.0                0.0
# std             0.587472                0.0                0.0
# min            -1.364818                0.0                0.0
# ...

# %%
dffilt = df.copy()
dffilt = dffilt[dffilt.cmd_vel__linear_x.notnull()]

# %%
dffilt.sample(10)
# Out:
#                                cmd_vel__angular_x  cmd_vel__angular_y  \
# 2018-04-12 12:57:13.077347584                 0.0                 0.0
# 2018-04-12 12:58:20.337309184                 0.0                 0.0
# 2018-04-12 12:57:59.953276928                 0.0                 0.0
# 2018-04-12 12:57:16.049223936                 0.0                 0.0
# 2018-04-12 12:57:10.345446400                 0.0                 0.0
# 2018-04-12 12:55:46.733436928                 0.0                 0.0
# 2018-04-12 12:55:12.658514688                 0.0                 0.0
# 2018-04-12 12:56:31.870279680                 0.0                 0.0
# 2018-04-12 12:58:22.665861376                 0.0                 0.0
# 2018-04-12 12:57:40.913335808                 0.0                 0.0
#
#                                cmd_vel__angular_z  cmd_vel__linear_x  \
# 2018-04-12 12:57:13.077347584            0.641048           0.990597
# ...

# %%
dffilt.shape
# Out:
# (4177, 55)

# %%
dffilt.columns
# Out:
# Index([u'cmd_vel__angular_x', u'cmd_vel__angular_y', u'cmd_vel__angular_z',
#        u'cmd_vel__linear_x', u'cmd_vel__linear_y', u'cmd_vel__linear_z',
#        u'imu__angular_velocity_covariance0',
#        u'imu__angular_velocity_covariance1',
#        u'imu__angular_velocity_covariance2',
#        u'imu__angular_velocity_covariance3',
#        u'imu__angular_velocity_covariance4',
#        u'imu__angular_velocity_covariance5',
#        u'imu__angular_velocity_covariance6',
#        u'imu__angular_velocity_covariance7',
#        u'imu__angular_velocity_covariance8', u'imu__angular_velocity_x',
#        u'imu__angular_velocity_y', u'imu__angular_velocity_z',
#        u'imu__linear_acceleration_covariance0',
#        u'imu__linear_acceleration_covariance1',
#        u'imu__linear_acceleration_covariance2',
#        u'imu__linear_acceleration_covariance3',
#        u'imu__linear_acceleration_covariance4',
#        u'imu__linear_acceleration_covariance5',
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(dffilt.index,dffilt.cmd_vel__linear_x)
plt.show()

# %%
dffilt2 = df.copy()
dffilt2 = dffilt2[dffilt2.imu__angular_velocity_z.notnull()]

# %%
dffilt2.shape
# Out:
# (0, 71)

# %%
import rosbag
bag = rosbag.Bag('../bags/imu_bag.bag')
A = bag.read_messages(topics=['/vel'])
#bag.close()

# %%
for B in A:
    print(B.message)

# %%
A.__attr__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-84-32a0191f92fe> in <module>()
# ----> 1 A.__attr__
#
# AttributeError: 'generator' object has no attribute '__attr__'
